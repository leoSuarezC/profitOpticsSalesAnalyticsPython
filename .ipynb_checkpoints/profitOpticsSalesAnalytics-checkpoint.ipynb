# %%
#allows to plot in the notebook
# %matplotlib inline
#import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

#get the dataFrames
xls = pd.ExcelFile('custItemInvHist.xlsx')
df1 = pd.read_excel(xls, 'Cust')
df2 = pd.read_excel(xls, 'Item')
df3 = pd.read_excel(xls, 'InvHist')
#df3.hist(column='GP')
ax = df3['GP'].plot(title = 'Gp general')

# %%
ax = df3.plot(subplots = True)

# %%
ax = df3.plot(title = 'Gp general', x = 'yearMonth', y = 'GP')

# %%
ax = df3['GP'].plot.hist(bins = 10)

# %%
ax = df3['GP'].plot.box()
